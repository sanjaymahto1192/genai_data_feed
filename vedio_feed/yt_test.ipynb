# %%
# !pip install openai-whisper
# Out:
# Collecting openai-whisper
#   Using cached openai_whisper-20231117-py3-none-any.whl
# Collecting numba (from openai-whisper)
#   Using cached numba-0.59.1-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper) (1.26.3)
# Requirement already satisfied: torch in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from openai-whisper) (2.3.0+cu121)
# Collecting tqdm (from openai-whisper)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting more-itertools (from openai-whisper)
#   Using cached more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting tiktoken (from openai-whisper)
#   Using cached tiktoken-0.6.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba->openai-whisper)
#   Using cached llvmlite-0.42.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Collecting regex>=2022.1.18 (from tiktoken->openai-whisper)
#   Using cached regex-2024.4.28-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: filelock in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper) (4.9.0)
# Requirement already satisfied: sympy in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper) (2024.2.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from torch->openai-whisper) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from tqdm->openai-whisper) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->openai-whisper) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->openai-whisper) (2021.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch->openai-whisper) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch->openai-whisper) (1.3.0)
# Using cached more_itertools-10.2.0-py3-none-any.whl (57 kB)
# Using cached numba-0.59.1-cp312-cp312-win_amd64.whl (2.7 MB)
# Using cached tiktoken-0.6.0-cp312-cp312-win_amd64.whl (798 kB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached llvmlite-0.42.0-cp312-cp312-win_amd64.whl (28.1 MB)
# Using cached regex-2024.4.28-cp312-cp312-win_amd64.whl (268 kB)
# Installing collected packages: tqdm, regex, more-itertools, llvmlite, tiktoken, numba, openai-whisper
# Successfully installed llvmlite-0.42.0 more-itertools-10.2.0 numba-0.59.1 openai-whisper-20231117 regex-2024.4.28 tiktoken-0.6.0 tqdm-4.66.4

# %%
# !pip install jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting click<9.0.0,>=8.1.3 (from jiwer)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\sanja\appdata\local\programs\python\python312\lib\site-packages (from click<9.0.0,>=8.1.3->jiwer) (0.4.6)
# Downloading jiwer-3.0.3-py3-none-any.whl (21 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------- ----------------------- 41.0/97.9 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 97.9/97.9 kB 1.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.6 MB 4.3 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.6 MB 6.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.2/1.6 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, click, jiwer
# Successfully installed click-8.1.7 jiwer-3.0.3 rapidfuzz-3.9.0

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#    ------- -------------------------------- 10.2/57.6 kB ? eta -:--:--
#    --------------------- ------------------ 30.7/57.6 kB 325.1 kB/s eta 0:00:01
#    ---------------------------------------- 57.6/57.6 kB 430.5 kB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
from pytube import YouTube

# %%
try:
    yt = YouTube('https://www.youtube.com/watch?v=p7HKvqRI_Bo')
except:
    print('Connection_error')

# %%
yt.streams.filter(file_extension='mp4')
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="24fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="22" mime_type="video/mp4" res="720p" fps="24fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">, <Stream: itag="137" mime_type="video/mp4" res="1080p" fps="24fps" vcodec="avc1.640028" progressive="False" type="video">, <Stream: itag="136" mime_type="video/mp4" res="720p" fps="24fps" vcodec="avc1.4d401f" progressive="False" type="video">, <Stream: itag="135" mime_type="video/mp4" res="480p" fps="24fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="134" mime_type="video/mp4" res="360p" fps="24fps" vcodec="avc1.4d401e" progressive="False" type="video">, <Stream: itag="133" mime_type="video/mp4" res="240p" fps="24fps" vcodec="avc1.4d4015" progressive="False" type="video">, <Stream: itag="160" mime_type="video/mp4" res="144p" fps="24fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">]

# %%
stream = yt.streams.get_by_itag(139)

# %%
stream.download('','market_basic.mp4')
# Out:
# 'D:\\Datascience Projects\\Projects\\genai_datafeed\\vedio_feed\\market_basic.mp4'

# %%
import whisper

# %%
model = whisper.load_model('base.en')
# Out:
# 100%|███████████████████████████████████████| 139M/139M [01:45<00:00, 1.37MiB/s]

# %%
result = model.transcribe('market_basic.mp4')

# %%
result
# Out:
# {'text': " In the 1600s, the Dutch East India Company employed hundreds of ships to trade gold, porcelain, spices, and silks around the globe. But running this massive operation wasn't cheap. In order to fund their expensive voyages, the company turned to private citizens, individuals who could invest money to support the trip in exchange for a share of the ship's profits. This practice allowed the company to afford even grander voyages, increasing profits for both themselves and their savvy investors. Selling these shares in coffeehouses and shipping ports across the continent, the Dutch East India Company unknowingly invented the world's first stock market. Since then, companies have been collecting funds from willing investors to support all kinds of businesses. And today, the stock market has schools, careers, and even whole television channels dedicated to understanding it. But the modern stock market is significantly more complicated than its original incarnation, so how do companies and investors use the market today? Let's imagine a new coffee company that decides to launch on the market. First, the company will advertise itself to big investors. If they think the company is a good idea, they get the first crack at investing and then sponsor the company's Initial Public Offering, or IPO. This launches the company onto the official public market, where any company or individual who believes the business could be profitable might buy a stock. Buying stocks makes those investors partial owners in the business. Their investment helps the company to grow, and as it becomes more successful, more buyers may see potential and start buying stocks. As demand for those stocks increases, so does their price, increasing the cost for prospective buyers, and raising the value of the company's stocks people already own. For the company, this increased interest helps fund new initiatives, and also boosts its overall market value by showing how many people are willing to invest in their idea. However, if for some reason a company starts to seem less profitable, the reverse can also happen. If investors think their stock value is going to decline, they'll sell their stocks with the hopes of making a profit before the company loses more value. As stocks are sold and demand for the stock goes down, the stock price falls, and with it, the company's market value. This can leave investors with big losses, unless the company starts to look profitable again. This seesaw of supply and demand is influenced by many factors. Companies are under the unavoidable influence of market forces, such as the fluctuating price of materials, changes in production technology, and the shifting costs of labor. Investors may be worried about changes in leadership, bad publicity, or larger factors like new laws and trade policies. And of course, plenty of investors are simply ready to sell valuable stocks and pursue personal interests. All these variables cause day-to-day noise in the market, which can make companies appear more or less successful, and in the stock market, appearing to lose value, often leads to losing investors, and in turn losing actual value. Human confidence in the market has the power to trigger everything from economic booms to financial crises, and this difficult-to-track variable is why most professionals promote reliable long-term investing over trying to make quick cash. However, experts are constantly building tools in efforts to increase their chances of success in this highly unpredictable system. But the stock market is not just for the rich and powerful. With the dawn of the internet, everyday investors can buy stocks in many of the exact same ways a large investor would. And as more people educate themselves about this complex system, they too can trade stocks, support the businesses they believe in, and pursue their financial goals. The first step is getting invested.",
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 12.68,
#    'text': ' In the 1600s, the Dutch East India Company employed hundreds of ships to trade gold,',
#    'tokens': [50363,
#     554,
#     262,
#     26143,
#     82,
#     11,
#     262,
#     10914,
#     3687,
#     3794,
#     5834,
#     9322,
#     5179,
#     286,
#     7937,
#     284,
#     3292,
#     3869,
#     11,
#     50997],
#    'temperature': 0.0,
#    'avg_logprob': -0.1530407008840077,
#    'compression_ratio': 1.4196891191709844,
#    'no_speech_prob': 0.07014793902635574},
#   {'id': 1,
#    'seek': 0,
#    'start': 12.68,
#    'end': 16.44,
#    'text': ' porcelain, spices, and silks around the globe.',
#    'tokens': [50997,
#     16964,
#     5276,
#     391,
#     11,
#     27952,
#     11,
#     290,
#     3313,
#     591,
#     1088,
#     262,
#     13342,
#     13,
#     51185],
#    'temperature': 0.0,
#    'avg_logprob': -0.1530407008840077,
#    'compression_ratio': 1.4196891191709844,
#    'no_speech_prob': 0.07014793902635574},
#   {'id': 2,
#    'seek': 0,
#    'start': 16.44,
#    'end': 19.400000000000002,
#    'text': " But running this massive operation wasn't cheap.",
#    'tokens': [51185, 887, 2491, 428, 4858, 4905, 2492, 470, 7026, 13, 51333],
#    'temperature': 0.0,
#    'avg_logprob': -0.1530407008840077,
#    'compression_ratio': 1.4196891191709844,
#    'no_speech_prob': 0.07014793902635574},
#   {'id': 3,
#    'seek': 0,
#    'start': 19.400000000000002,
#    'end': 25.240000000000002,
#    'text': ' In order to fund their expensive voyages, the company turned to private citizens, individuals',
#    'tokens': [51333,
#     554,
#     1502,
#     284,
#     1814,
#     511,
#     5789,
#     23291,
#     1095,
#     11,
#     262,
#     1664,
#     2900,
#     284,
#     2839,
#     4290,
#     11,
#     3925,
#     51625],
#    'temperature': 0.0,
#    'avg_logprob': -0.1530407008840077,
#    'compression_ratio': 1.4196891191709844,
#    'no_speech_prob': 0.07014793902635574},
#   {'id': 4,
#    'seek': 2524,
#    'start': 25.24,
#    'end': 30.799999999999997,
#    'text': " who could invest money to support the trip in exchange for a share of the ship's profits.",
#    'tokens': [50363,
#     508,
#     714,
#     1325,
#     1637,
#     284,
#     1104,
#     262,
#     5296,
#     287,
#     5163,
#     329,
#     257,
#     2648,
#     286,
#     262,
#     4074,
#     338,
#     10177,
#     13,
#     50641],
#    'temperature': 0.0,
#    'avg_logprob': -0.15163202983577076,
#    'compression_ratio': 1.6075949367088607,
#    'no_speech_prob': 0.14650008082389832},
#   {'id': 5,
#    'seek': 2524,
#    'start': 30.799999999999997,
#    'end': 36.0,
#    'text': ' This practice allowed the company to afford even grander voyages, increasing profits for',
#    'tokens': [50641,
#     770,
#     3357,
#     3142,
#     262,
#     1664,
#     284,
#     5368,
#     772,
#     1036,
#     4066,
#     23291,
#     1095,
#     11,
#     3649,
#     10177,
#     329,
#     50901],
#    'temperature': 0.0,
#    'avg_logprob': -0.15163202983577076,
#    'compression_ratio': 1.6075949367088607,
#    'no_speech_prob': 0.14650008082389832},
#   {'id': 6,
#    'seek': 2524,
#    'start': 36.0,
#    'end': 39.92,
#    'text': ' both themselves and their savvy investors.',
#    'tokens': [50901, 1111, 2405, 290, 511, 32800, 7713, 13, 51097],
#    'temperature': 0.0,
#    'avg_logprob': -0.15163202983577076,
#    'compression_ratio': 1.6075949367088607,
#    'no_speech_prob': 0.14650008082389832},
#   {'id': 7,
#    'seek': 2524,
#    'start': 39.92,
#    'end': 45.239999999999995,
#    'text': ' Selling these shares in coffeehouses and shipping ports across the continent, the Dutch East',
#    'tokens': [51097,
#     47919,
#     777,
#     7303,
#     287,
#     6891,
#     20089,
#     290,
#     8440,
#     14090,
#     1973,
#     262,
#     15549,
#     11,
#     262,
#     10914,
#     3687,
#     51363],
#    'temperature': 0.0,
#    'avg_logprob': -0.15163202983577076,
#    'compression_ratio': 1.6075949367088607,
#    'no_speech_prob': 0.14650008082389832},
#   {'id': 8,
#    'seek': 2524,
#    'start': 45.239999999999995,
#    'end': 50.8,
#    'text': " India Company unknowingly invented the world's first stock market.",
#    'tokens': [51363,
#     3794,
#     5834,
#     39472,
#     4420,
#     15646,
#     262,
#     995,
#     338,
#     717,
#     4283,
#     1910,
#     13,
#     51641],
#    'temperature': 0.0,
#    'avg_logprob': -0.15163202983577076,
#    'compression_ratio': 1.6075949367088607,
#    'no_speech_prob': 0.14650008082389832},
#   {'id': 9,
#    'seek': 5080,
#    'start': 50.8,
#    'end': 55.239999999999995,
#    'text': ' Since then, companies have been collecting funds from willing investors to support all',
#    'tokens': [50363,
#     4619,
#     788,
#     11,
#     2706,
#     423,
#     587,
#     13157,
#     5153,
#     422,
#     4684,
#     7713,
#     284,
#     1104,
#     477,
#     50585],
#    'temperature': 0.0,
#    'avg_logprob': -0.1502419622320878,
#    'compression_ratio': 1.679245283018868,
#    'no_speech_prob': 0.425296425819397},
#   {'id': 10,
#    'seek': 5080,
#    'start': 55.239999999999995,
#    'end': 56.959999999999994,
#    'text': ' kinds of businesses.',
#    'tokens': [50585, 6982, 286, 5692, 13, 50671],
#    'temperature': 0.0,
#    'avg_logprob': -0.1502419622320878,
#    'compression_ratio': 1.679245283018868,
#    'no_speech_prob': 0.425296425819397},
#   {'id': 11,
#    'seek': 5080,
#    'start': 56.959999999999994,
#    'end': 63.04,
#    'text': ' And today, the stock market has schools, careers, and even whole television channels dedicated',
#    'tokens': [50671,
#     843,
#     1909,
#     11,
#     262,
#     4283,
#     1910,
#     468,
#     4266,
#     11,
#     16179,
#     11,
#     290,
#     772,
#     2187,
#     5581,
#     9619,
#     7256,
#     50975],
#    'temperature': 0.0,
#    'avg_logprob': -0.1502419622320878,
#    'compression_ratio': 1.679245283018868,
#    'no_speech_prob': 0.425296425819397},
#   {'id': 12,
#    'seek': 5080,
#    'start': 63.04,
#    'end': 64.56,
#    'text': ' to understanding it.',
#    'tokens': [50975, 284, 4547, 340, 13, 51051],
#    'temperature': 0.0,
#    'avg_logprob': -0.1502419622320878,
#    'compression_ratio': 1.679245283018868,
#    'no_speech_prob': 0.425296425819397},
#   {'id': 13,
#    'seek': 5080,
#    'start': 64.56,
#    'end': 70.03999999999999,
#    'text': ' But the modern stock market is significantly more complicated than its original incarnation,',
#    'tokens': [51051,
#     887,
#     262,
#     3660,
#     4283,
#     1910,
#     318,
#     5566,
#     517,
#     8253,
#     621,
#     663,
#     2656,
#     29185,
#     11,
#     51325],
#    'temperature': 0.0,
#    'avg_logprob': -0.1502419622320878,
#    'compression_ratio': 1.679245283018868,
#    'no_speech_prob': 0.425296425819397},
#   {'id': 14,
#    'seek': 5080,
#    'start': 70.03999999999999,
#    'end': 74.52,
#    'text': ' so how do companies and investors use the market today?',
#    'tokens': [51325,
#     523,
#     703,
#     466,
#     2706,
#     290,
#     7713,
#     779,
#     262,
#     1910,
#     1909,
#     30,
#     51549],
#    'temperature': 0.0,
#    'avg_logprob': -0.1502419622320878,
#    'compression_ratio': 1.679245283018868,
#    'no_speech_prob': 0.425296425819397},
#   {'id': 15,
#    'seek': 5080,
#    'start': 74.52,
#    'end': 78.88,
#    'text': " Let's imagine a new coffee company that decides to launch on the market.",
#    'tokens': [51549,
#     3914,
#     338,
#     5967,
#     257,
#     649,
#     6891,
#     1664,
#     326,
#     13267,
#     284,
#     4219,
#     319,
#     262,
#     1910,
#     13,
#     51767],
#    'temperature': 0.0,
#    'avg_logprob': -0.1502419622320878,
#    'compression_ratio': 1.679245283018868,
#    'no_speech_prob': 0.425296425819397},
#   {'id': 16,
#    'seek': 7888,
#    'start': 78.88,
#    'end': 82.56,
#    'text': ' First, the company will advertise itself to big investors.',
#    'tokens': [50363,
#     3274,
#     11,
#     262,
#     1664,
#     481,
#     32740,
#     2346,
#     284,
#     1263,
#     7713,
#     13,
#     50547],
#    'temperature': 0.0,
#    'avg_logprob': -0.12155005806370785,
#    'compression_ratio': 1.6771653543307086,
#    'no_speech_prob': 0.1366117298603058},
#   {'id': 17,
#    'seek': 7888,
#    'start': 82.56,
#    'end': 86.67999999999999,
#    'text': ' If they think the company is a good idea, they get the first crack at investing and then',
#    'tokens': [50547,
#     1002,
#     484,
#     892,
#     262,
#     1664,
#     318,
#     257,
#     922,
#     2126,
#     11,
#     484,
#     651,
#     262,
#     717,
#     8469,
#     379,
#     14771,
#     290,
#     788,
#     50753],
#    'temperature': 0.0,
#    'avg_logprob': -0.12155005806370785,
#    'compression_ratio': 1.6771653543307086,
#    'no_speech_prob': 0.1366117298603058},
#   {'id': 18,
#    'seek': 7888,
#    'start': 86.67999999999999,
#    'end': 91.6,
#    'text': " sponsor the company's Initial Public Offering, or IPO.",
#    'tokens': [50753,
#     17487,
#     262,
#     1664,
#     338,
#     20768,
#     5094,
#     3242,
#     1586,
#     11,
#     393,
#     41805,
#     13,
#     50999],
#    'temperature': 0.0,
#    'avg_logprob': -0.12155005806370785,
#    'compression_ratio': 1.6771653543307086,
#    'no_speech_prob': 0.1366117298603058},
#   {'id': 19,
#    'seek': 7888,
#    'start': 91.6,
#    'end': 96.36,
#    'text': ' This launches the company onto the official public market, where any company or individual',
#    'tokens': [50999,
#     770,
#     18617,
#     262,
#     1664,
#     4291,
#     262,
#     1743,
#     1171,
#     1910,
#     11,
#     810,
#     597,
#     1664,
#     393,
#     1981,
#     51237],
#    'temperature': 0.0,
#    'avg_logprob': -0.12155005806370785,
#    'compression_ratio': 1.6771653543307086,
#    'no_speech_prob': 0.1366117298603058},
#   {'id': 20,
#    'seek': 7888,
#    'start': 96.36,
#    'end': 100.28,
#    'text': ' who believes the business could be profitable might buy a stock.',
#    'tokens': [51237,
#     508,
#     5804,
#     262,
#     1597,
#     714,
#     307,
#     17967,
#     1244,
#     2822,
#     257,
#     4283,
#     13,
#     51433],
#    'temperature': 0.0,
#    'avg_logprob': -0.12155005806370785,
#    'compression_ratio': 1.6771653543307086,
#    'no_speech_prob': 0.1366117298603058},
#   {'id': 21,
#    'seek': 7888,
#    'start': 100.28,
#    'end': 104.52,
#    'text': ' Buying stocks makes those investors partial owners in the business.',
#    'tokens': [51433,
#     9842,
#     1112,
#     14420,
#     1838,
#     883,
#     7713,
#     13027,
#     4393,
#     287,
#     262,
#     1597,
#     13,
#     51645],
#    'temperature': 0.0,
#    'avg_logprob': -0.12155005806370785,
#    'compression_ratio': 1.6771653543307086,
#    'no_speech_prob': 0.1366117298603058},
#   {'id': 22,
#    'seek': 10452,
#    'start': 104.52,
#    'end': 109.19999999999999,
#    'text': ' Their investment helps the company to grow, and as it becomes more successful, more buyers',
#    'tokens': [50363,
#     5334,
#     4896,
#     5419,
#     262,
#     1664,
#     284,
#     1663,
#     11,
#     290,
#     355,
#     340,
#     4329,
#     517,
#     4388,
#     11,
#     517,
#     14456,
#     50597],
#    'temperature': 0.0,
#    'avg_logprob': -0.1304984694545709,
#    'compression_ratio': 1.7962264150943397,
#    'no_speech_prob': 0.4551181197166443},
#   {'id': 23,
#    'seek': 10452,
#    'start': 109.19999999999999,
#    'end': 112.24,
#    'text': ' may see potential and start buying stocks.',
#    'tokens': [50597, 743, 766, 2785, 290, 923, 7067, 14420, 13, 50749],
#    'temperature': 0.0,
#    'avg_logprob': -0.1304984694545709,
#    'compression_ratio': 1.7962264150943397,
#    'no_speech_prob': 0.4551181197166443},
#   {'id': 24,
#    'seek': 10452,
#    'start': 112.24,
#    'end': 117.32,
#    'text': ' As demand for those stocks increases, so does their price, increasing the cost for prospective',
#    'tokens': [50749,
#     1081,
#     3512,
#     329,
#     883,
#     14420,
#     5732,
#     11,
#     523,
#     857,
#     511,
#     2756,
#     11,
#     3649,
#     262,
#     1575,
#     329,
#     17530,
#     51003],
#    'temperature': 0.0,
#    'avg_logprob': -0.1304984694545709,
#    'compression_ratio': 1.7962264150943397,
#    'no_speech_prob': 0.4551181197166443},
#   {'id': 25,
#    'seek': 10452,
#    'start': 117.32,
#    'end': 122.5,
#    'text': " buyers, and raising the value of the company's stocks people already own.",
#    'tokens': [51003,
#     14456,
#     11,
#     290,
#     8620,
#     262,
#     1988,
#     286,
#     262,
#     1664,
#     338,
#     14420,
#     661,
#     1541,
#     898,
#     13,
#     51262],
#    'temperature': 0.0,
#    'avg_logprob': -0.1304984694545709,
#    'compression_ratio': 1.7962264150943397,
#    'no_speech_prob': 0.4551181197166443},
#   {'id': 26,
#    'seek': 10452,
#    'start': 122.5,
#    'end': 128.07999999999998,
#    'text': ' For the company, this increased interest helps fund new initiatives, and also boosts its',
#    'tokens': [51262,
#     1114,
#     262,
#     1664,
#     11,
#     428,
#     3220,
#     1393,
#     5419,
#     1814,
#     649,
#     15446,
#     11,
#     290,
#     635,
#     31822,
#     663,
#     51541],
#    'temperature': 0.0,
#    'avg_logprob': -0.1304984694545709,
#    'compression_ratio': 1.7962264150943397,
#    'no_speech_prob': 0.4551181197166443},
#   {'id': 27,
#    'seek': 10452,
#    'start': 128.07999999999998,
#    'end': 133.48,
#    'text': ' overall market value by showing how many people are willing to invest in their idea.',
#    'tokens': [51541,
#     4045,
#     1910,
#     1988,
#     416,
#     4478,
#     703,
#     867,
#     661,
#     389,
#     4684,
#     284,
#     1325,
#     287,
#     511,
#     2126,
#     13,
#     51811],
#    'temperature': 0.0,
#    'avg_logprob': -0.1304984694545709,
#    'compression_ratio': 1.7962264150943397,
#    'no_speech_prob': 0.4551181197166443},
#   {'id': 28,
#    'seek': 13348,
#    'start': 133.48,
#    'end': 138.2,
#    'text': ' However, if for some reason a company starts to seem less profitable, the reverse can',
#    'tokens': [50363,
#     2102,
#     11,
#     611,
#     329,
#     617,
#     1738,
#     257,
#     1664,
#     4940,
#     284,
#     1283,
#     1342,
#     17967,
#     11,
#     262,
#     9575,
#     460,
#     50599],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 29,
#    'seek': 13348,
#    'start': 138.2,
#    'end': 139.67999999999998,
#    'text': ' also happen.',
#    'tokens': [50599, 635, 1645, 13, 50673],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 30,
#    'seek': 13348,
#    'start': 139.67999999999998,
#    'end': 144.04,
#    'text': " If investors think their stock value is going to decline, they'll sell their stocks with",
#    'tokens': [50673,
#     1002,
#     7713,
#     892,
#     511,
#     4283,
#     1988,
#     318,
#     1016,
#     284,
#     7794,
#     11,
#     484,
#     1183,
#     3677,
#     511,
#     14420,
#     351,
#     50891],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 31,
#    'seek': 13348,
#    'start': 144.04,
#    'end': 148.16,
#    'text': ' the hopes of making a profit before the company loses more value.',
#    'tokens': [50891,
#     262,
#     7176,
#     286,
#     1642,
#     257,
#     7630,
#     878,
#     262,
#     1664,
#     14754,
#     517,
#     1988,
#     13,
#     51097],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 32,
#    'seek': 13348,
#    'start': 148.16,
#    'end': 153.07999999999998,
#    'text': ' As stocks are sold and demand for the stock goes down, the stock price falls, and with',
#    'tokens': [51097,
#     1081,
#     14420,
#     389,
#     2702,
#     290,
#     3512,
#     329,
#     262,
#     4283,
#     2925,
#     866,
#     11,
#     262,
#     4283,
#     2756,
#     8953,
#     11,
#     290,
#     351,
#     51343],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 33,
#    'seek': 13348,
#    'start': 153.07999999999998,
#    'end': 155.32,
#    'text': " it, the company's market value.",
#    'tokens': [51343, 340, 11, 262, 1664, 338, 1910, 1988, 13, 51455],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 34,
#    'seek': 13348,
#    'start': 155.32,
#    'end': 159.72,
#    'text': ' This can leave investors with big losses, unless the company starts to look profitable',
#    'tokens': [51455,
#     770,
#     460,
#     2666,
#     7713,
#     351,
#     1263,
#     9089,
#     11,
#     4556,
#     262,
#     1664,
#     4940,
#     284,
#     804,
#     17967,
#     51675],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 35,
#    'seek': 13348,
#    'start': 159.72,
#    'end': 161.28,
#    'text': ' again.',
#    'tokens': [51675, 757, 13, 51753],
#    'temperature': 0.0,
#    'avg_logprob': -0.11009954554694039,
#    'compression_ratio': 1.8346456692913387,
#    'no_speech_prob': 0.06295664608478546},
#   {'id': 36,
#    'seek': 16128,
#    'start': 161.36,
#    'end': 165.92,
#    'text': ' This seesaw of supply and demand is influenced by many factors.',
#    'tokens': [50367,
#     770,
#     7224,
#     707,
#     286,
#     5127,
#     290,
#     3512,
#     318,
#     12824,
#     416,
#     867,
#     5087,
#     13,
#     50595],
#    'temperature': 0.0,
#    'avg_logprob': -0.14617221190197632,
#    'compression_ratio': 1.6583629893238434,
#    'no_speech_prob': 0.2808409333229065},
#   {'id': 37,
#    'seek': 16128,
#    'start': 165.92,
#    'end': 170.48,
#    'text': ' Companies are under the unavoidable influence of market forces, such as the fluctuating',
#    'tokens': [50595,
#     24382,
#     389,
#     739,
#     262,
#     37645,
#     4588,
#     286,
#     1910,
#     3386,
#     11,
#     884,
#     355,
#     262,
#     19180,
#     11927,
#     50823],
#    'temperature': 0.0,
#    'avg_logprob': -0.14617221190197632,
#    'compression_ratio': 1.6583629893238434,
#    'no_speech_prob': 0.2808409333229065},
#   {'id': 38,
#    'seek': 16128,
#    'start': 170.48,
#    'end': 176.72,
#    'text': ' price of materials, changes in production technology, and the shifting costs of labor.',
#    'tokens': [50823,
#     2756,
#     286,
#     5696,
#     11,
#     2458,
#     287,
#     3227,
#     3037,
#     11,
#     290,
#     262,
#     15852,
#     3484,
#     286,
#     4827,
#     13,
#     51135],
#    'temperature': 0.0,
#    'avg_logprob': -0.14617221190197632,
#    'compression_ratio': 1.6583629893238434,
#    'no_speech_prob': 0.2808409333229065},
#   {'id': 39,
#    'seek': 16128,
#    'start': 176.72,
#    'end': 181.08,
#    'text': ' Investors may be worried about changes in leadership, bad publicity, or larger factors',
#    'tokens': [51135,
#     38898,
#     743,
#     307,
#     7960,
#     546,
#     2458,
#     287,
#     5531,
#     11,
#     2089,
#     19403,
#     11,
#     393,
#     4025,
#     5087,
#     51353],
#    'temperature': 0.0,
#    'avg_logprob': -0.14617221190197632,
#    'compression_ratio': 1.6583629893238434,
#    'no_speech_prob': 0.2808409333229065},
#   {'id': 40,
#    'seek': 16128,
#    'start': 181.08,
#    'end': 183.84,
#    'text': ' like new laws and trade policies.',
#    'tokens': [51353, 588, 649, 3657, 290, 3292, 4788, 13, 51491],
#    'temperature': 0.0,
#    'avg_logprob': -0.14617221190197632,
#    'compression_ratio': 1.6583629893238434,
#    'no_speech_prob': 0.2808409333229065},
#   {'id': 41,
#    'seek': 16128,
#    'start': 183.84,
#    'end': 189.0,
#    'text': ' And of course, plenty of investors are simply ready to sell valuable stocks and pursue personal',
#    'tokens': [51491,
#     843,
#     286,
#     1781,
#     11,
#     6088,
#     286,
#     7713,
#     389,
#     2391,
#     3492,
#     284,
#     3677,
#     8119,
#     14420,
#     290,
#     10660,
#     2614,
#     51749],
#    'temperature': 0.0,
#    'avg_logprob': -0.14617221190197632,
#    'compression_ratio': 1.6583629893238434,
#    'no_speech_prob': 0.2808409333229065},
#   {'id': 42,
#    'seek': 16128,
#    'start': 189.0,
#    'end': 190.16,
#    'text': ' interests.',
#    'tokens': [51749, 5353, 13, 51807],
#    'temperature': 0.0,
#    'avg_logprob': -0.14617221190197632,
#    'compression_ratio': 1.6583629893238434,
#    'no_speech_prob': 0.2808409333229065},
#   {'id': 43,
#    'seek': 19016,
#    'start': 190.16,
#    'end': 194.48,
#    'text': ' All these variables cause day-to-day noise in the market, which can make companies appear',
#    'tokens': [50363,
#     1439,
#     777,
#     9633,
#     2728,
#     1110,
#     12,
#     1462,
#     12,
#     820,
#     7838,
#     287,
#     262,
#     1910,
#     11,
#     543,
#     460,
#     787,
#     2706,
#     1656,
#     50579],
#    'temperature': 0.0,
#    'avg_logprob': -0.12350201156904113,
#    'compression_ratio': 1.7472118959107807,
#    'no_speech_prob': 0.2154889702796936},
#   {'id': 44,
#    'seek': 19016,
#    'start': 194.48,
#    'end': 199.84,
#    'text': ' more or less successful, and in the stock market, appearing to lose value, often leads',
#    'tokens': [50579,
#     517,
#     393,
#     1342,
#     4388,
#     11,
#     290,
#     287,
#     262,
#     4283,
#     1910,
#     11,
#     12655,
#     284,
#     4425,
#     1988,
#     11,
#     1690,
#     5983,
#     50847],
#    'temperature': 0.0,
#    'avg_logprob': -0.12350201156904113,
#    'compression_ratio': 1.7472118959107807,
#    'no_speech_prob': 0.2154889702796936},
#   {'id': 45,
#    'seek': 19016,
#    'start': 199.84,
#    'end': 204.28,
#    'text': ' to losing investors, and in turn losing actual value.',
#    'tokens': [50847,
#     284,
#     6078,
#     7713,
#     11,
#     290,
#     287,
#     1210,
#     6078,
#     4036,
#     1988,
#     13,
#     51069],
#    'temperature': 0.0,
#    'avg_logprob': -0.12350201156904113,
#    'compression_ratio': 1.7472118959107807,
#    'no_speech_prob': 0.2154889702796936},
#   {'id': 46,
#    'seek': 19016,
#    'start': 204.28,
#    'end': 208.96,
#    'text': ' Human confidence in the market has the power to trigger everything from economic booms',
#    'tokens': [51069,
#     5524,
#     6628,
#     287,
#     262,
#     1910,
#     468,
#     262,
#     1176,
#     284,
#     7616,
#     2279,
#     422,
#     3034,
#     1489,
#     3150,
#     51303],
#    'temperature': 0.0,
#    'avg_logprob': -0.12350201156904113,
#    'compression_ratio': 1.7472118959107807,
#    'no_speech_prob': 0.2154889702796936},
#   {'id': 47,
#    'seek': 19016,
#    'start': 208.96,
#    'end': 214.51999999999998,
#    'text': ' to financial crises, and this difficult-to-track variable is why most professionals promote',
#    'tokens': [51303,
#     284,
#     3176,
#     25712,
#     11,
#     290,
#     428,
#     2408,
#     12,
#     1462,
#     12,
#     11659,
#     7885,
#     318,
#     1521,
#     749,
#     11153,
#     7719,
#     51581],
#    'temperature': 0.0,
#    'avg_logprob': -0.12350201156904113,
#    'compression_ratio': 1.7472118959107807,
#    'no_speech_prob': 0.2154889702796936},
#   {'id': 48,
#    'seek': 19016,
#    'start': 214.51999999999998,
#    'end': 218.8,
#    'text': ' reliable long-term investing over trying to make quick cash.',
#    'tokens': [51581,
#     9314,
#     890,
#     12,
#     4354,
#     14771,
#     625,
#     2111,
#     284,
#     787,
#     2068,
#     5003,
#     13,
#     51795],
#    'temperature': 0.0,
#    'avg_logprob': -0.12350201156904113,
#    'compression_ratio': 1.7472118959107807,
#    'no_speech_prob': 0.2154889702796936},
#   {'id': 49,
#    'seek': 21880,
#    'start': 218.8,
#    'end': 223.16000000000003,
#    'text': ' However, experts are constantly building tools in efforts to increase their chances',
#    'tokens': [50363,
#     2102,
#     11,
#     6154,
#     389,
#     7558,
#     2615,
#     4899,
#     287,
#     4040,
#     284,
#     2620,
#     511,
#     8395,
#     50581],
#    'temperature': 0.0,
#    'avg_logprob': -0.12198262948256272,
#    'compression_ratio': 1.6448275862068966,
#    'no_speech_prob': 0.4032858908176422},
#   {'id': 50,
#    'seek': 21880,
#    'start': 223.16000000000003,
#    'end': 226.32000000000002,
#    'text': ' of success in this highly unpredictable system.',
#    'tokens': [50581, 286, 1943, 287, 428, 4047, 22900, 1080, 13, 50739],
#    'temperature': 0.0,
#    'avg_logprob': -0.12198262948256272,
#    'compression_ratio': 1.6448275862068966,
#    'no_speech_prob': 0.4032858908176422},
#   {'id': 51,
#    'seek': 21880,
#    'start': 226.32000000000002,
#    'end': 229.48000000000002,
#    'text': ' But the stock market is not just for the rich and powerful.',
#    'tokens': [50739,
#     887,
#     262,
#     4283,
#     1910,
#     318,
#     407,
#     655,
#     329,
#     262,
#     5527,
#     290,
#     3665,
#     13,
#     50897],
#    'temperature': 0.0,
#    'avg_logprob': -0.12198262948256272,
#    'compression_ratio': 1.6448275862068966,
#    'no_speech_prob': 0.4032858908176422},
#   {'id': 52,
#    'seek': 21880,
#    'start': 229.48000000000002,
#    'end': 234.64000000000001,
#    'text': ' With the dawn of the internet, everyday investors can buy stocks in many of the exact same ways',
#    'tokens': [50897,
#     2080,
#     262,
#     17577,
#     286,
#     262,
#     5230,
#     11,
#     10908,
#     7713,
#     460,
#     2822,
#     14420,
#     287,
#     867,
#     286,
#     262,
#     2748,
#     976,
#     2842,
#     51155],
#    'temperature': 0.0,
#    'avg_logprob': -0.12198262948256272,
#    'compression_ratio': 1.6448275862068966,
#    'no_speech_prob': 0.4032858908176422},
#   {'id': 53,
#    'seek': 21880,
#    'start': 234.64000000000001,
#    'end': 236.48000000000002,
#    'text': ' a large investor would.',
#    'tokens': [51155, 257, 1588, 15811, 561, 13, 51247],
#    'temperature': 0.0,
#    'avg_logprob': -0.12198262948256272,
#    'compression_ratio': 1.6448275862068966,
#    'no_speech_prob': 0.4032858908176422},
#   {'id': 54,
#    'seek': 21880,
#    'start': 236.48000000000002,
#    'end': 241.8,
#    'text': ' And as more people educate themselves about this complex system, they too can trade stocks,',
#    'tokens': [51247,
#     843,
#     355,
#     517,
#     661,
#     20771,
#     2405,
#     546,
#     428,
#     3716,
#     1080,
#     11,
#     484,
#     1165,
#     460,
#     3292,
#     14420,
#     11,
#     51513],
#    'temperature': 0.0,
#    'avg_logprob': -0.12198262948256272,
#    'compression_ratio': 1.6448275862068966,
#    'no_speech_prob': 0.4032858908176422},
#   {'id': 55,
#    'seek': 21880,
#    'start': 241.8,
#    'end': 245.56,
#    'text': ' support the businesses they believe in, and pursue their financial goals.',
#    'tokens': [51513,
#     1104,
#     262,
#     5692,
#     484,
#     1975,
#     287,
#     11,
#     290,
#     10660,
#     511,
#     3176,
#     4661,
#     13,
#     51701],
#    'temperature': 0.0,
#    'avg_logprob': -0.12198262948256272,
#    'compression_ratio': 1.6448275862068966,
#    'no_speech_prob': 0.4032858908176422},
#   {'id': 56,
#    'seek': 24556,
#    'start': 245.56,
#    'end': 268.88,
#    'text': ' The first step is getting invested.',
#    'tokens': [50363, 383, 717, 2239, 318, 1972, 13356, 13, 51529],
#    'temperature': 0.0,
#    'avg_logprob': -0.2647757053375244,
#    'compression_ratio': 0.8333333333333334,
#    'no_speech_prob': 0.5774959325790405}],
#  'language': 'en'}

# %%
print(result.keys())
# Out:
# dict_keys(['text', 'segments', 'language'])

# %%
print(result['text'])
# Out:
#  In the 1600s, the Dutch East India Company employed hundreds of ships to trade gold, porcelain, spices, and silks around the globe. But running this massive operation wasn't cheap. In order to fund their expensive voyages, the company turned to private citizens, individuals who could invest money to support the trip in exchange for a share of the ship's profits. This practice allowed the company to afford even grander voyages, increasing profits for both themselves and their savvy investors. Selling these shares in coffeehouses and shipping ports across the continent, the Dutch East India Company unknowingly invented the world's first stock market. Since then, companies have been collecting funds from willing investors to support all kinds of businesses. And today, the stock market has schools, careers, and even whole television channels dedicated to understanding it. But the modern stock market is significantly more complicated than its original incarnation, so how do companies and investors use the market today? Let's imagine a new coffee company that decides to launch on the market. First, the company will advertise itself to big investors. If they think the company is a good idea, they get the first crack at investing and then sponsor the company's Initial Public Offering, or IPO. This launches the company onto the official public market, where any company or individual who believes the business could be profitable might buy a stock. Buying stocks makes those investors partial owners in the business. Their investment helps the company to grow, and as it becomes more successful, more buyers may see potential and start buying stocks. As demand for those stocks increases, so does their price, increasing the cost for prospective buyers, and raising the value of the company's stocks people already own. For the company, this increased interest helps fund new initiatives, and also boosts its overall market value by showing how many people are willing to invest in their idea. However, if for some reason a company starts to seem less profitable, the reverse can also happen. If investors think their stock value is going to decline, they'll sell their stocks with the hopes of making a profit before the company loses more value. As stocks are sold and demand for the stock goes down, the stock price falls, and with it, the company's market value. This can leave investors with big losses, unless the company starts to look profitable again. This seesaw of supply and demand is influenced by many factors. Companies are under the unavoidable influence of market forces, such as the fluctuating price of materials, changes in production technology, and the shifting costs of labor. Investors may be worried about changes in leadership, bad publicity, or larger factors like new laws and trade policies. And of course, plenty of investors are simply ready to sell valuable stocks and pursue personal interests. All these variables cause day-to-day noise in the market, which can make companies appear more or less successful, and in the stock market, appearing to lose value, often leads to losing investors, and in turn losing actual value. Human confidence in the market has the power to trigger everything from economic booms to financial crises, and this difficult-to-track variable is why most professionals promote reliable long-term investing over trying to make quick cash. However, experts are constantly building tools in efforts to increase their chances of success in this highly unpredictable system. But the stock market is not just for the rich and powerful. With the dawn of the internet, everyday investors can buy stocks in many of the exact same ways a large investor would. And as more people educate themselves about this complex system, they too can trade stocks, support the businesses they believe in, and pursue their financial goals. The first step is getting invested.

# %%
with open('yt_trnscription.txt','w')as file:
    file.write(result['text'])
